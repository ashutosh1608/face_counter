# %% [markdown]
# <a href="https://colab.research.google.com/github/ashutosh1608/face_counter/blob/master/Part_1_Gathering_and_preparing_the_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/theAIGuysCode/OIDv4_ToolKit.git
# Out:
# Cloning into 'OIDv4_ToolKit'...
# remote: Enumerating objects: 444, done.
# remote: Total 444 (delta 0), reused 0 (delta 0), pack-reused 444
# Receiving objects: 100% (444/444), 34.09 MiB | 9.11 MiB/s, done.
# Resolving deltas: 100% (158/158), done.

# %%
! pip install -r /content/OIDv4_ToolKit/requirements.txt
# Out:
# ...
#      |████████████████████████████████| 3.2MB 2.7MB/s
# ...
#      |████████████████████████████████| 6.3MB 24.0MB/s
# ...
#      |████████████████████████████████| 51kB 7.3MB/s
# ...
#   Found existing installation: botocore 1.17.9
#     Uninstalling botocore-1.17.9:
#       Successfully uninstalled botocore-1.17.9
#   Found existing installation: rsa 4.6
#     Uninstalling rsa-4.6:
#       Successfully uninstalled rsa-4.6
# ...

# %%
! python /content/OIDv4_ToolKit/main.py downloader --classes Human_head --type_csv train --limit 2500
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Human head.
#    [ERROR] | Missing the class-descriptions-boxable.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] y
# ...145%, 0 MB, 45465 KB/s, 0 seconds passed
# ...

# %%
! python /content/OIDv4_ToolKit/convert_annotations.py
# Out:
# Currently in subdirectory: train
# Converting annotations for class:  Human head
# 100% 2500/2500 [02:28<00:00, 16.82it/s]

# %%
# !rm -rf "/content/OID/Dataset/train/Human head/Label"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !zip -r "/content/drive/My Drive/Head Counter/hh.zip" "/content/OID/Dataset/train/Human head"
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/OID/Dataset/train/Human head/35e9af288c765828.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Human head/e3346378ec3af7b5.jpg (deflated 1%)
#   adding: content/OID/Dataset/train/Human head/87241d477cf0d346.txt (deflated 43%)
#   adding: content/OID/Dataset/train/Human head/40bba61938bd6f2c.txt (deflated 48%)
#   adding: content/OID/Dataset/train/Human head/dee07e8e490302dc.txt (deflated 36%)
#   adding: content/OID/Dataset/train/Human head/eb0e7db00fee15b6.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Human head/b7c99e66a1e4d68c.txt (deflated 30%)
#   adding: content/OID/Dataset/train/Human head/bf10293882696548.txt (deflated 27%)
#   adding: content/OID/Dataset/train/Human head/d53e329b469185c5.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Human head/49f9541c465a1bba.txt (deflated 49%)
#   adding: content/OID/Dataset/train/Human head/b3edaebececa75ca.jpg (deflated 0%)
# ...
